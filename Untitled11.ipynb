# %% [markdown]
# <a href="https://colab.research.google.com/github/Shravanisk205/DC/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#support vector regression implementation
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVR

# %%
X=np.array([600,800,1000,1200,1400]).reshape(-1,1)
y=np.array([150000,180000,200000,2200000,2400000])

# %%
#create svr model with radial basis function(RBF) kernel
svr=SVR(kernel='rbf',C=1000,epsilon=10000)
#Uses Radial Basis Function (RBF) Kernel, which helps capture non-linear patterns.
#Regularization parameter – Higher C makes the model more sensitive to outliers
#Margin of tolerance – Defines a range where errors are ignored
svr.fit(X,y)
# Out:
# SVR(C=1000, epsilon=10000)

# %%
#predict prizes
y_pred=svr.predict(X)

# %%
#plot results
plt.scatter(X,y,color='blue',label="Actual Price")
plt.plot(X,y_pred,color='red',label="SVR prediction")
plt.legend()
plt.show()
